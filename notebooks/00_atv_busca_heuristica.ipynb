# %% [markdown]
# # Referencia
#
# Para a implementação, usamos a refência [https://pt.wikipedia.org/wiki/Algoritmo_A*](https://pt.wikipedia.org/wiki/Algoritmo_A*)

# %% [markdown]
# # Imports

# %%
import heapq
from copy import deepcopy

# %% [markdown]
# # Methods

# %%
class Node:
    def __init__(
            self,
            state,
            parent=None,
            move=None,
            g=0,
            MOVE= {'up': (-1, 0), 'down': (1, 0), 'left': (0, -1), 'right': (0, 1)},
            GOAL_STATE= [[1, 2, 3], [4, 5, 6], [7, 8, 0]]
        ):
        self.state = state
        self.parent = parent
        self.move = move
        self.g = g  # Custo acumulado
        self.h = self.heuristic()  # Heurística: distância de Manhattan
        self.f = self.g + self.h   # f = g + h
        self.GOAL_STATE = GOAL_STATE
        self.MOVES = MOVE

    def __lt__(self, other):
        return self.f < other.f

    def __eq__(self, other):
        return self.state == other.state

    def find_blank(self):
        """Encontra a posição do espaço vazio (0)."""
        for i in range(3):
            for j in range(3):
                if self.state[i][j] == 0:
                    return i, j

    def heuristic(self):
        """Distância de Manhattan total das peças ao objetivo."""
        distance = 0
        for i in range(3):
            for j in range(3):
                val = self.state[i][j]
                if val != 0:
                    goal_i = (val - 1) // 3
                    goal_j = (val - 1) % 3
                    distance += abs(i - goal_i) + abs(j - goal_j)
        return distance

    def get_neighbors(self):
        """Gera os vizinhos do estado atual."""
        neighbors = []
        blank_i, blank_j = self.find_blank()
        for move, (di, dj) in self.MOVES.items():
            new_i, new_j = blank_i + di, blank_j + dj
            if 0 <= new_i < 3 and 0 <= new_j < 3:
                new_state = deepcopy(self.state)
                new_state[blank_i][blank_j], new_state[new_i][new_j] = new_state[new_i][new_j], new_state[blank_i][blank_j]
                neighbors.append(Node(new_state, self, move, self.g + 1))
        return neighbors

    def path(self):
        """Reconstrói o caminho da solução."""
        node, steps = self, []
        while node:
            steps.append(node)
            node = node.parent
        return steps[::-1]

    def print_state(self):
        for row in self.state:
            print(row)

def print_frontier(frontier):
    print("Fronteira atual:")
    for node in frontier:
        print(f"  f={node.f} (g={node.g}, h={node.h}), movimento: {node.move}")
        for row in node.state:
            print("   ", row)
        print()
    print("=" * 40)

def a_star(start_state, goal_state):
    start_node = Node(start_state)
    frontier = []
    heapq.heappush(frontier, start_node)
    explored = set()
    step = 0

    while frontier:
        print(f"\n--- Etapa {step} ---")
        print_frontier(frontier)

        current = heapq.heappop(frontier)

        if current.state == goal_state:
            return current.path()

        explored.add(tuple(tuple(row) for row in current.state))

        for neighbor in current.get_neighbors():
            state_tuple = tuple(tuple(row) for row in neighbor.state)
            if state_tuple not in explored:
                heapq.heappush(frontier, neighbor)

        step += 1

    return None

# %% [markdown]
# # Parameters

# %%
# Estado final desejado
GOAL_STATE = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 0]
]

# Movimentos possíveis
MOVES = {
    'up': (-1, 0),
    'down': (1, 0),
    'left': (0, -1),
    'right': (0, 1)
}
initial_state = [
    [1, 8, 2],
    [4, 3, 0],
    [7, 6, 5]
]

# %% [markdown]
# # Process

# %%
# ----------- EXECUÇÃO ------------
print("Executando algoritmo A*...\nEstado inicial:")
for row in initial_state:
    print(row)

solution_path = a_star(initial_state, GOAL_STATE)

if solution_path:
    print("\n🔍 Solução encontrada!")
    print("Número de movimentos:", len(solution_path) - 1)
    total_cost = solution_path[-1].g
    print("Custo total:", total_cost)

    print("\n📌 Caminho da solução:")
    for i, node in enumerate(solution_path):
        print(f"\nNível {i} | Movimento: {node.move} | g: {node.g}, h: {node.h}, f: {node.f}")
        for row in node.state:
            print(row)
else:
    print("❌ Nenhuma solução encontrada.")
# Out:
# Executando algoritmo A*...
# Estado inicial:
# [1, 8, 2]
# [4, 3, 0]
# [7, 6, 5]
#
# --- Etapa 0 ---
# Fronteira atual:
#   f=9 (g=0, h=9), movimento: None
#     [1, 8, 2]
#     [4, 3, 0]
#     [7, 6, 5]
#
# ========================================
#
# --- Etapa 1 ---
# Fronteira atual:
#   f=9 (g=1, h=8), movimento: down
#     [1, 8, 2]
#     [4, 3, 5]
#     [7, 6, 0]
#
#   f=11 (g=1, h=10), movimento: up
#     [1, 8, 0]
#     [4, 3, 2]
#     [7, 6, 5]
#
#   f=9 (g=1, h=8), movimento: left
#     [1, 8, 2]
#     [4, 0, 3]
#     [7, 6, 5]
#
# ========================================
#
# --- Etapa 2 ---
# Fronteira atual:
#   f=9 (g=1, h=8), movimento: left
#     [1, 8, 2]
#     [4, 0, 3]
#     [7, 6, 5]
#
#   f=11 (g=1, h=10), movimento: up
#     [1, 8, 0]
#     [4, 3, 2]
#     [7, 6, 5]
#
#   f=9 (g=2, h=7), movimento: left
#     [1, 8, 2]
#     [4, 3, 5]
#     [7, 0, 6]
#
# ========================================
#
# --- Etapa 3 ---
# Fronteira atual:
#   f=9 (g=2, h=7), movimento: left
#     [1, 8, 2]
#     [4, 3, 5]
#     [7, 0, 6]
#
#   f=9 (g=2, h=7), movimento: down
#     [1, 8, 2]
#     [4, 6, 3]
#     [7, 0, 5]
#
#   f=9 (g=2, h=7), movimento: up
#     [1, 0, 2]
#     [4, 8, 3]
#     [7, 6, 5]
#
#   f=11 (g=1, h=10), movimento: up
#     [1, 8, 0]
#     [4, 3, 2]
#     [7, 6, 5]
#
#   f=11 (g=2, h=9), movimento: left
#     [1, 8, 2]
#     [0, 4, 3]
#     [7, 6, 5]
#
# ========================================
#
# --- Etapa 4 ---
# Fronteira atual:
#   f=9 (g=2, h=7), movimento: up
#     [1, 0, 2]
#     [4, 8, 3]
#     [7, 6, 5]
#
#   f=9 (g=2, h=7), movimento: down
#     [1, 8, 2]
#     [4, 6, 3]
#     [7, 0, 5]
#
#   f=11 (g=2, h=9), movimento: left
#     [1, 8, 2]
#     [0, 4, 3]
#     [7, 6, 5]
#
#   f=11 (g=1, h=10), movimento: up
#     [1, 8, 0]
#     [4, 3, 2]
#     [7, 6, 5]
#
#   f=11 (g=3, h=8), movimento: up
#     [1, 8, 2]
#     [4, 0, 5]
#     [7, 3, 6]
#
#   f=11 (g=3, h=8), movimento: left
#     [1, 8, 2]
#     [4, 3, 5]
#     [0, 7, 6]
#
# ========================================
#
# --- Etapa 5 ---
# Fronteira atual:
#   f=9 (g=2, h=7), movimento: down
#     [1, 8, 2]
#     [4, 6, 3]
#     [7, 0, 5]
#
#   f=11 (g=3, h=8), movimento: up
#     [1, 8, 2]
#     [4, 0, 5]
#     [7, 3, 6]
#
#   f=9 (g=3, h=6), movimento: right
#     [1, 2, 0]
#     [4, 8, 3]
#     [7, 6, 5]
#
#   f=11 (g=1, h=10), movimento: up
#     [1, 8, 0]
#     [4, 3, 2]
#     [7, 6, 5]
#
#   f=11 (g=3, h=8), movimento: left
#     [1, 8, 2]
#     [4, 3, 5]
#     [0, 7, 6]
#
#   f=11 (g=3, h=8), movimento: left
#     [0, 1, 2]
#     [4, 8, 3]
#     [7, 6, 5]
#
#   f=11 (g=2, h=9), movimento: left
#     [1, 8, 2]
#     [0, 4, 3]
#     [7, 6, 5]
#
# ========================================
#
# --- Etapa 6 ---
# Fronteira atual:
#   f=9 (g=3, h=6), movimento: right
#     [1, 2, 0]
#     [4, 8, 3]
#     [7, 6, 5]
#
#   f=9 (g=3, h=6), movimento: right
#     [1, 8, 2]
#     [4, 6, 3]
#     [7, 5, 0]
#
#   f=11 (g=3, h=8), movimento: left
#     [0, 1, 2]
#     [4, 8, 3]
#     [7, 6, 5]
#
#   f=11 (g=3, h=8), movimento: up
#     [1, 8, 2]
#     [4, 0, 5]
#     [7, 3, 6]
#
#   f=11 (g=3, h=8), movimento: left
#     [1, 8, 2]
#     [4, 3, 5]
#     [0, 7, 6]
#
#   f=11 (g=2, h=9), movimento: left
#     [1, 8, 2]
#     [0, 4, 3]
#     [7, 6, 5]
#
#   f=11 (g=3, h=8), movimento: left
#     [1, 8, 2]
#     [4, 6, 3]
#     [0, 7, 5]
#
#   f=11 (g=1, h=10), movimento: up
#     [1, 8, 0]
#     [4, 3, 2]
#     [7, 6, 5]
#
# ========================================
#
# --- Etapa 7 ---
# Fronteira atual:
#   f=9 (g=3, h=6), movimento: right
#     [1, 8, 2]
#     [4, 6, 3]
#     [7, 5, 0]
#
#   f=9 (g=4, h=5), movimento: down
#     [1, 2, 3]
#     [4, 8, 0]
#     [7, 6, 5]
#
#   f=11 (g=3, h=8), movimento: left
#     [0, 1, 2]
#     [4, 8, 3]
#     [7, 6, 5]
#
#   f=11 (g=3, h=8), movimento: left
#     [1, 8, 2]
#     [4, 3, 5]
#     [0, 7, 6]
#
#   f=11 (g=1, h=10), movimento: up
#     [1, 8, 0]
#     [4, 3, 2]
#     [7, 6, 5]
#
#   f=11 (g=2, h=9), movimento: left
#     [1, 8, 2]
#     [0, 4, 3]
#     [7, 6, 5]
#
#   f=11 (g=3, h=8), movimento: left
#     [1, 8, 2]
#     [4, 6, 3]
#     [0, 7, 5]
#
#   f=11 (g=3, h=8), movimento: up
#     [1, 8, 2]
#     [4, 0, 5]
#     [7, 3, 6]
#
# ========================================
#
# --- Etapa 8 ---
# Fronteira atual:
#   f=9 (g=4, h=5), movimento: down
#     [1, 2, 3]
#     [4, 8, 0]
#     [7, 6, 5]
#
#   f=11 (g=1, h=10), movimento: up
#     [1, 8, 0]
#     [4, 3, 2]
#     [7, 6, 5]
#
#   f=11 (g=3, h=8), movimento: left
#     [0, 1, 2]
#     [4, 8, 3]
#     [7, 6, 5]
#
#   f=11 (g=3, h=8), movimento: left
#     [1, 8, 2]
#     [4, 3, 5]
#     [0, 7, 6]
#
#   f=11 (g=3, h=8), movimento: up
#     [1, 8, 2]
#     [4, 0, 5]
#     [7, 3, 6]
#
#   f=11 (g=2, h=9), movimento: left
#     [1, 8, 2]
#     [0, 4, 3]
#     [7, 6, 5]
#
#   f=11 (g=3, h=8), movimento: left
#     [1, 8, 2]
#     [4, 6, 3]
#     [0, 7, 5]
#
#   f=11 (g=4, h=7), movimento: up
#     [1, 8, 2]
#     [4, 6, 0]
#     [7, 5, 3]
#
# ========================================
#
# --- Etapa 9 ---
# Fronteira atual:
#   f=9 (g=5, h=4), movimento: down
#     [1, 2, 3]
#     [4, 8, 5]
#     [7, 6, 0]
#
#   f=11 (g=3, h=8), movimento: left
#     [0, 1, 2]
#     [4, 8, 3]
#     [7, 6, 5]
#
#   f=11 (g=3, h=8), movimento: left
#     [1, 8, 2]
#     [4, 6, 3]
#     [0, 7, 5]
#
#   f=11 (g=1, h=10), movimento: up
#     [1, 8, 0]
#     [4, 3, 2]
#     [7, 6, 5]
#
#   f=11 (g=3, h=8), movimento: up
#     [1, 8, 2]
#     [4, 0, 5]
#     [7, 3, 6]
#
#   f=11 (g=2, h=9), movimento: left
#     [1, 8, 2]
#     [0, 4, 3]
#     [7, 6, 5]
#
#   f=11 (g=4, h=7), movimento: up
#     [1, 8, 2]
#     [4, 6, 0]
#     [7, 5, 3]
#
#   f=11 (g=3, h=8), movimento: left
#     [1, 8, 2]
#     [4, 3, 5]
#     [0, 7, 6]
#
#   f=11 (g=5, h=6), movimento: left
#     [1, 2, 3]
#     [4, 0, 8]
#     [7, 6, 5]
#
# ========================================
#
# --- Etapa 10 ---
# Fronteira atual:
#   f=9 (g=6, h=3), movimento: left
#     [1, 2, 3]
#     [4, 8, 5]
#     [7, 0, 6]
#
#   f=11 (g=3, h=8), movimento: left
#     [1, 8, 2]
#     [4, 6, 3]
#     [0, 7, 5]
#
#   f=11 (g=4, h=7), movimento: up
#     [1, 8, 2]
#     [4, 6, 0]
#     [7, 5, 3]
#
#   f=11 (g=3, h=8), movimento: left
#     [0, 1, 2]
#     [4, 8, 3]
#     [7, 6, 5]
#
#   f=11 (g=3, h=8), movimento: up
#     [1, 8, 2]
#     [4, 0, 5]
#     [7, 3, 6]
#
#   f=11 (g=2, h=9), movimento: left
#     [1, 8, 2]
#     [0, 4, 3]
#     [7, 6, 5]
#
#   f=11 (g=5, h=6), movimento: left
#     [1, 2, 3]
#     [4, 0, 8]
#     [7, 6, 5]
#
#   f=11 (g=3, h=8), movimento: left
#     [1, 8, 2]
#     [4, 3, 5]
#     [0, 7, 6]
#
#   f=11 (g=1, h=10), movimento: up
#     [1, 8, 0]
#     [4, 3, 2]
#     [7, 6, 5]
#
# ========================================
#
# --- Etapa 11 ---
# Fronteira atual:
#   f=9 (g=7, h=2), movimento: up
#     [1, 2, 3]
#     [4, 0, 5]
#     [7, 8, 6]
#
#   f=11 (g=4, h=7), movimento: up
#     [1, 8, 2]
#     [4, 6, 0]
#     [7, 5, 3]
#
#   f=11 (g=5, h=6), movimento: left
#     [1, 2, 3]
#     [4, 0, 8]
#     [7, 6, 5]
#
#   f=11 (g=3, h=8), movimento: left
#     [1, 8, 2]
#     [4, 6, 3]
#     [0, 7, 5]
#
#   f=11 (g=3, h=8), movimento: up
#     [1, 8, 2]
#     [4, 0, 5]
#     [7, 3, 6]
#
#   f=11 (g=2, h=9), movimento: left
#     [1, 8, 2]
#     [0, 4, 3]
#     [7, 6, 5]
#
#   f=11 (g=1, h=10), movimento: up
#     [1, 8, 0]
#     [4, 3, 2]
#     [7, 6, 5]
#
#   f=11 (g=3, h=8), movimento: left
#     [1, 8, 2]
#     [4, 3, 5]
#     [0, 7, 6]
#
#   f=11 (g=3, h=8), movimento: left
#     [0, 1, 2]
#     [4, 8, 3]
#     [7, 6, 5]
#
#   f=11 (g=7, h=4), movimento: left
#     [1, 2, 3]
#     [4, 8, 5]
#     [0, 7, 6]
#
# ========================================
#
# --- Etapa 12 ---
# Fronteira atual:
#   f=9 (g=8, h=1), movimento: right
#     [1, 2, 3]
#     [4, 5, 0]
#     [7, 8, 6]
#
#   f=11 (g=4, h=7), movimento: up
#     [1, 8, 2]
#     [4, 6, 0]
#     [7, 5, 3]
#
#   f=11 (g=5, h=6), movimento: left
#     [1, 2, 3]
#     [4, 0, 8]
#     [7, 6, 5]
#
#   f=11 (g=3, h=8), movimento: left
#     [1, 8, 2]
#     [4, 6, 3]
#     [0, 7, 5]
#
#   f=11 (g=3, h=8), movimento: up
#     [1, 8, 2]
#     [4, 0, 5]
#     [7, 3, 6]
#
#   f=11 (g=1, h=10), movimento: up
#     [1, 8, 0]
#     [4, 3, 2]
#     [7, 6, 5]
#
#   f=11 (g=7, h=4), movimento: left
#     [1, 2, 3]
#     [4, 8, 5]
#     [0, 7, 6]
#
#   f=11 (g=3, h=8), movimento: left
#     [1, 8, 2]
#     [4, 3, 5]
#     [0, 7, 6]
#
#   f=11 (g=3, h=8), movimento: left
#     [0, 1, 2]
#     [4, 8, 3]
#     [7, 6, 5]
#
#   f=11 (g=8, h=3), movimento: up
#     [1, 0, 3]
#     [4, 2, 5]
#     [7, 8, 6]
#
#   f=11 (g=8, h=3), movimento: left
#     [1, 2, 3]
#     [0, 4, 5]
#     [7, 8, 6]
#
#   f=11 (g=2, h=9), movimento: left
#     [1, 8, 2]
#     [0, 4, 3]
#     [7, 6, 5]
#
# ========================================
#
# --- Etapa 13 ---
# Fronteira atual:
#   f=9 (g=9, h=0), movimento: down
#     [1, 2, 3]
#     [4, 5, 6]
#     [7, 8, 0]
#
#   f=11 (g=4, h=7), movimento: up
#     [1, 8, 2]
#     [4, 6, 0]
#     [7, 5, 3]
#
#   f=11 (g=5, h=6), movimento: left
#     [1, 2, 3]
#     [4, 0, 8]
#     [7, 6, 5]
#
#   f=11 (g=3, h=8), movimento: left
#     [1, 8, 2]
#     [4, 6, 3]
#     [0, 7, 5]
#
#   f=11 (g=3, h=8), movimento: up
#     [1, 8, 2]
#     [4, 0, 5]
#     [7, 3, 6]
#
#   f=11 (g=7, h=4), movimento: left
#     [1, 2, 3]
#     [4, 8, 5]
#     [0, 7, 6]
#
#   f=11 (g=2, h=9), movimento: left
#     [1, 8, 2]
#     [0, 4, 3]
#     [7, 6, 5]
#
#   f=11 (g=3, h=8), movimento: left
#     [1, 8, 2]
#     [4, 3, 5]
#     [0, 7, 6]
#
#   f=11 (g=3, h=8), movimento: left
#     [0, 1, 2]
#     [4, 8, 3]
#     [7, 6, 5]
#
#   f=11 (g=8, h=3), movimento: up
#     [1, 0, 3]
#     [4, 2, 5]
#     [7, 8, 6]
#
#   f=11 (g=8, h=3), movimento: left
#     [1, 2, 3]
#     [0, 4, 5]
#     [7, 8, 6]
#
#   f=11 (g=9, h=2), movimento: up
#     [1, 2, 0]
#     [4, 5, 3]
#     [7, 8, 6]
#
#   f=11 (g=1, h=10), movimento: up
#     [1, 8, 0]
#     [4, 3, 2]
#     [7, 6, 5]
#
# ========================================
#
# 🔍 Solução encontrada!
# Número de movimentos: 9
# Custo total: 9
#
# 📌 Caminho da solução:
#
# Nível 0 | Movimento: None | g: 0, h: 9, f: 9
# [1, 8, 2]
# [4, 3, 0]
# [7, 6, 5]
#
# Nível 1 | Movimento: left | g: 1, h: 8, f: 9
# [1, 8, 2]
# [4, 0, 3]
# [7, 6, 5]
#
# Nível 2 | Movimento: up | g: 2, h: 7, f: 9
# [1, 0, 2]
# [4, 8, 3]
# [7, 6, 5]
#
# Nível 3 | Movimento: right | g: 3, h: 6, f: 9
# [1, 2, 0]
# [4, 8, 3]
# [7, 6, 5]
#
# Nível 4 | Movimento: down | g: 4, h: 5, f: 9
# [1, 2, 3]
# [4, 8, 0]
# [7, 6, 5]
#
# Nível 5 | Movimento: down | g: 5, h: 4, f: 9
# [1, 2, 3]
# [4, 8, 5]
# [7, 6, 0]
#
# Nível 6 | Movimento: left | g: 6, h: 3, f: 9
# [1, 2, 3]
# [4, 8, 5]
# [7, 0, 6]
#
# Nível 7 | Movimento: up | g: 7, h: 2, f: 9
# [1, 2, 3]
# [4, 0, 5]
# [7, 8, 6]
#
# Nível 8 | Movimento: right | g: 8, h: 1, f: 9
# [1, 2, 3]
# [4, 5, 0]
# [7, 8, 6]
#
# Nível 9 | Movimento: down | g: 9, h: 0, f: 9
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 0]

# %%
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
